# %%
import pandas as pd

# %%
olympic=pd.read_csv(r'C:\Users\DELL3521\Desktop\athlete_events.csv')
olympic
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 0            1                           A Dijiang   M  24.0   180.0    80.0
# 1            2                            A Lamusi   M  23.0   170.0    60.0
# 2            3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5            Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 5            5            Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 6            5            Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 7            5            Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 8            5            Christine Jacoba Aaftink   F  27.0   185.0    82.0
# 9            5            Christine Jacoba Aaftink   F  27.0   185.0    82.0
# 10           6                     Per Knut Aaland   M  31.0   188.0    75.0
# ...

# %%
olympic.to_csv(R"D:\olympics\olympic.csv",sep=',',header=True,index=False)

# %%
olympic.sort_values('Year')
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 214333  107607         Fritz Richard Gustav Schuft   M  19.0     NaN     NaN
# 244717  122526             Pierre Alexandre Tuffri   M  19.0     NaN     NaN
# 244716  122526             Pierre Alexandre Tuffri   M  19.0     NaN     NaN
# 23912    12563           Conrad Helmut Fritz Bcker   M  25.0     NaN     NaN
# 23913    12563           Conrad Helmut Fritz Bcker   M  25.0     NaN     NaN
# 23914    12563           Conrad Helmut Fritz Bcker   M  25.0     NaN     NaN
# 23915    12563           Conrad Helmut Fritz Bcker   M  25.0     NaN     NaN
# 23916    12563           Conrad Helmut Fritz Bcker   M  25.0     NaN     NaN
# 23917    12563           Conrad Helmut Fritz Bcker   M  25.0     NaN     NaN
# 23918    12563           Conrad Helmut Fritz Bcker   M  25.0     NaN     NaN
# 75128    38123                          Carl Galle   M  23.0   154.0    45.0
# ...

# %%
y=olympic.loc[olympic['Year']==2016].sort_values('Sport')
y
# Out:
#             ID                                     Name Sex   Age  Height  \
# 8387      4614                    Mohamad Khairul Anuar   M  24.0   171.0
# 263362  131792                                Wu Jiaxin   F  19.0   164.0
# 228956  114956                Inna Yakovlevna Stepanova   F  26.0   176.0
# 216463  108673                              Olqa Senyuk   F  25.0   175.0
# 50194    25830  Marcus Vincius Carvalho Lopes D'Almeida   M  18.0   183.0
# 2297      1277                 Carolina Aguirre Giraldo   F  20.0   160.0
# 2298      1277                 Carolina Aguirre Giraldo   F  20.0   160.0
# 50195    25830  Marcus Vincius Carvalho Lopes D'Almeida   M  18.0   183.0
# 236783  118715                Karoline Lusitania Tatafu   F  18.0   176.0
# 107504   54336                         Hans Arne Jensen   M  18.0   181.0
# 260444  130337                    Muhammad Hanif Wijaya   M  19.0   171.0
# 182924   91935                        David Pasqualucci   M  20.0   181.0
# ...

# %%
y.loc[y['Event']=="Archery Men's Individual"]
# Out:
#             ID                                     Name Sex   Age  Height  \
# 50194    25830  Marcus Vincius Carvalho Lopes D'Almeida   M  18.0   183.0
# 107504   54336                         Hans Arne Jensen   M  18.0   181.0
# 260444  130337                    Muhammad Hanif Wijaya   M  19.0   171.0
# 182923   91935                        David Pasqualucci   M  20.0   181.0
# 192201   96508                               Alec Potts   M  20.0   185.0
# 245484  122927                               Ryan Tyack   M  25.0   186.0
# 77305    39227                               Mete Gazoz   M  17.0   181.0
# 147400   73977                Elas Javier Malav Burgos    M  26.0   180.0
# 68102    34788                Antonio Fernndez Fernndez   M  25.0   184.0
# 55423    28424                          Mitch Dielemans   M  23.0   186.0
# 5681      3201                     Miguel Alvario Garca   M  22.0   180.0
# 49610    25559                             Areneo David   M  21.0   164.0
# ...

# %%
oly=olympic.drop_duplicates(subset=['NOC','Games','City','Sport','Event'],keep='first')
oly
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 0            1                           A Dijiang   M  24.0   180.0    80.0
# 1            2                            A Lamusi   M  23.0   170.0    60.0
# 2            3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5            Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 5            5            Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 6            5            Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 7            5            Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 8            5            Christine Jacoba Aaftink   F  27.0   185.0    82.0
# 9            5            Christine Jacoba Aaftink   F  27.0   185.0    82.0
# 10           6                     Per Knut Aaland   M  31.0   188.0    75.0
# ...

# %%
oly.to_csv(R"D:\olympics\oly.csv",sep=',',header=True,index=False)

# %%
country=olympic.loc[(olympic['Medal']=='Gold')|(olympic['Medal']=='Silver')|(olympic['Medal']=='Bronze')]
country
# Out:
#             ID                                       Name Sex   Age  Height  \
# 3            4                       Edgar Lindenau Aabye   M  34.0     NaN
# 37          15                       Arvo Ossian Aaltonen   M  30.0     NaN
# 38          15                       Arvo Ossian Aaltonen   M  30.0     NaN
# 40          16                   Juhamatti Tapio Aaltonen   M  28.0   184.0
# 41          17                    Paavo Johannes Aaltonen   M  28.0   175.0
# 42          17                    Paavo Johannes Aaltonen   M  28.0   175.0
# 44          17                    Paavo Johannes Aaltonen   M  28.0   175.0
# 48          17                    Paavo Johannes Aaltonen   M  28.0   175.0
# 50          17                    Paavo Johannes Aaltonen   M  32.0   175.0
# 60          20                         Kjetil Andr Aamodt   M  20.0   176.0
# 61          20                         Kjetil Andr Aamodt   M  20.0   176.0
# ...

# %%
country.shape
# Out:
# (39783, 15)

# %%
olympic.Medal.dropna().shape
# Out:
# (39783,)

# %%
country.loc[country['NOC']=='IND']
# Out:
#             ID                             Name Sex   Age  Height  Weight  \
# 4732      2699                      Shaukat Ali   M  30.0     NaN     NaN
# 4736      2703                 Syed Mushtaq Ali   M  22.0   165.0    61.0
# 5032      2864              Richard James Allen   M  25.0   172.0     NaN
# 5033      2864              Richard James Allen   M  30.0   172.0     NaN
# 5034      2864              Richard James Allen   M  34.0   172.0     NaN
# 8192      4518       Joseph Anthony "Joe" Antic   M  29.0   168.0    59.0
# 10274     5618            Sardar Mohammad Aslam   M   NaN     NaN     NaN
# 21208    11197              Vasudevan Bhaskaran   M  29.0   174.0    68.0
# 21815    11520      Govinda Billimogaputtaswamy   M  20.0   171.0    60.0
# 22004    11601                   Abhinav Bindra   M  25.0   173.0    70.0
# 24657    12911              Lal Shah S. Bokhari   M  23.0   173.0     NaN
# 29022    15011  Frank Gerald Singlehurst Brewin   M  22.0     NaN     NaN
# ...

# %%
c=country.drop_duplicates(subset=['Year','Season','NOC','Sport','Event','Medal'],keep='first')
c
# Out:
#             ID                                       Name Sex   Age  Height  \
# 3            4                       Edgar Lindenau Aabye   M  34.0     NaN
# 37          15                       Arvo Ossian Aaltonen   M  30.0     NaN
# 38          15                       Arvo Ossian Aaltonen   M  30.0     NaN
# 40          16                   Juhamatti Tapio Aaltonen   M  28.0   184.0
# 41          17                    Paavo Johannes Aaltonen   M  28.0   175.0
# 42          17                    Paavo Johannes Aaltonen   M  28.0   175.0
# 44          17                    Paavo Johannes Aaltonen   M  28.0   175.0
# 48          17                    Paavo Johannes Aaltonen   M  28.0   175.0
# 50          17                    Paavo Johannes Aaltonen   M  32.0   175.0
# 60          20                         Kjetil Andr Aamodt   M  20.0   176.0
# 61          20                         Kjetil Andr Aamodt   M  20.0   176.0
# ...

# %%
c['Year'].max()
# Out:
# 2016

# %%
c['NOC'].value_counts()
# Out:
# USA    2823
# URS    1197
# GER    1004
# GBR     919
# FRA     879
# ITA     722
# SWE     657
# CHN     595
# RUS     584
# AUS     519
# GDR     519
# HUN     510
# JPN     482
# CAN     475
# NOR     474
# FIN     471
# NED     407
# SUI     346
# AUT     326
# KOR     316
# POL     310
# ROU     304
# FRG     243
# BUL     223
# CUB     214
# DEN     211
# BEL     171
# TCH     171
# GRE     151
# ESP     150
#        ...
# KUW       2
# WIF       2
# GRN       2
# UAR       2
# SRI       2
# NEP       1
# AHO       1
# KOS       1
# IRQ       1
# MKD       1
# MNE       1
# BAR       1
# PAR       1
# GUA       1
# TOG       1
# BER       1
# GAB       1
# JOR       1
# SUD       1
# ERI       1
# MRI       1
# DJI       1
# SEN       1
# ISV       1
# MON       1
# FIJ       1
# GUY       1
# TGA       1
# CYP       1
# BOT       1
# Name: NOC, Length: 149, dtype: int64

# %%
c.to_csv(R"D:\olympics\count.csv",sep=',',header=True,index=False)

# %%
olympic['Team'].nunique()
# Out:
# 1184

# %%
olympic['NOC'].unique()
# Out:
# array(['CHN', 'DEN', 'NED', 'USA', 'FIN', 'NOR', 'ROU', 'EST', 'FRA',
#        'MAR', 'ESP', 'EGY', 'IRI', 'BUL', 'ITA', 'CHA', 'AZE', 'SUD',
#        'RUS', 'ARG', 'CUB', 'BLR', 'GRE', 'CMR', 'TUR', 'CHI', 'MEX',
#        'URS', 'NCA', 'HUN', 'NGR', 'ALG', 'KUW', 'BRN', 'PAK', 'IRQ',
#        'UAR', 'LIB', 'QAT', 'MAS', 'GER', 'CAN', 'IRL', 'AUS', 'RSA',
#        'ERI', 'TAN', 'JOR', 'TUN', 'LBA', 'BEL', 'DJI', 'PLE', 'COM',
#        'KAZ', 'BRU', 'IND', 'KSA', 'SYR', 'MDV', 'ETH', 'UAE', 'YAR',
#        'INA', 'PHI', 'SGP', 'UZB', 'KGZ', 'TJK', 'EUN', 'JPN', 'CGO',
#        'SUI', 'BRA', 'FRG', 'GDR', 'MON', 'ISR', 'URU', 'SWE', 'ISV',
#        'SRI', 'ARM', 'CIV', 'KEN', 'BEN', 'UKR', 'GBR', 'GHA', 'SOM',
#        'LAT', 'NIG', 'MLI', 'AFG', 'POL', 'CRC', 'PAN', 'GEO', 'SLO',
#        'CRO', 'GUY', 'NZL', 'POR', 'PAR', 'ANG', 'VEN', 'COL', 'BAN',
#        'PER', 'ESA', 'PUR', 'UGA', 'HON', 'ECU', 'TKM', 'MRI', 'SEY',
# ...

# %%
olympic['Year'].max()
# Out:
# 2016

# %%
olympic.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
olympic.count()
# Out:
# ID        271116
# Name      271116
# Sex       271116
# Age       261642
# Height    210945
# Weight    208241
# Team      271116
# NOC       271116
# Games     271116
# Year      271116
# Season    271116
# City      271116
# Sport     271116
# Event     271116
# Medal      39783
# dtype: int64

# %%
olympic.shape
# Out:
# (271116, 15)

# %%
c

# %%
c['NOC'].nunique()

# %%
reg=pd.read_csv(r'C:\Users\DELL3521\Desktop\noc_regions.csv')
reg

# %%
reg['region'].nunique()

# %%
reg['region'].count()

# %%
reg['NOC'].count()

# %%
reg['region']

# %%
reg['NOC'].nunique()

# %%
country1=pd.merge(c,reg,on='NOC')
country1
del country1['notes']
country1

# %%
country1['region'].nunique()

# %%
country1['region'].nunique()

# %%
country1.to_csv(R"D:\olympics\countrydashboard.csv",sep=',',header=True,index=False)

# %%
country1['NOC'].value_counts()

# %%
c

# %%
olympic
